# %%
from fastai2.vision.all import *

# %%
path = untar_data(URLs.PETS)/'images'

# %%
URLs
# Out:
# fastai2.data.external.URLs

# %%
def is_cat(x): return x[0].isupper()

# %%
is_cat('abC')
# Out:
# False

# %%
is_cat('Abc')
# Out:
# True

# %%
dls = ImageDataLoaders.from_name_func(path, get_image_files(path), valid_pct=0.2, seed=42, label_func=is_cat, item_tfms=Resize(224))

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)

# %%
learn.fine_tune(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.152774</td>
#       <td>0.038604</td>
#       <td>0.012179</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.055862</td>
#       <td>0.014303</td>
#       <td>0.003383</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>

# %%
import ipywidgets as widgets

# %%
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
img=PILImage.create(uploader.data[0])

# %%
img.to_thumb(192)
# Out:
# <PIL.Image.Image image mode=RGB size=192x108 at 0x7F1021489EE0>

# %%
is_cat,_,probs = learn.predict(img)

# %%
is_cat
# Out:
# 'True'

# %%
probs
# Out:
# tensor([2.1308e-05, 9.9998e-01])

# %%
print(f"Is this a cat?: {is_cat}.")
# Out:
# Is this a cat?: True.

# %%
print(f"Probability it is a cat: {probs[1].item():.6f}")
# Out:
# Probability it is a cat: 0.999979
