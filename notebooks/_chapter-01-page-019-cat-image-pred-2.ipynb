# %%
from fastai2.vision.all import *

# %%
path = untar_data(URLs.PETS)/'images'

# %%
URLs
# Out:
# fastai2.data.external.URLs

# %%
def is_cat(x): return x[0].isupper()

# %%
is_cat('abC')
# Out:
# False

# %%
is_cat('Abc')
# Out:
# True

# %%
dls = ImageDataLoaders.from_name_func(path, get_image_files(path), valid_pct=0.2, seed=42, label_func=is_cat, item_tfms=Resize(224))

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)

# %%
learn.fine_tune(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.179982</td>
#       <td>0.036258</td>
#       <td>0.011502</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.053086</td>
#       <td>0.015797</td>
#       <td>0.005413</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
import ipywidgets as widgets

# %%
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
img=PILImage.create(uploader.data[0])

# %%
img.to_thumb(192)
# Out:
# <PIL.Image.Image image mode=RGB size=184x192 at 0x7FEB64DE4550>

# %%
is_cat,_,probs = learn.predict(img)

# %%
is_cat
# Out:
# 'False'

# %%
probs
# Out:
# tensor([0.9978, 0.0022])

# %%
print(f"Is this a cat?: {is_cat}.")
# Out:
# Is this a cat?: False.

# %%
print(f"Probability it is a cat: {probs[1].item():.6f}")
# Out:
# Probability it is a cat: 0.002178
